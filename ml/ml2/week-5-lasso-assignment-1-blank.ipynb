# %% [markdown]
# # Regression Week 5: Feature Selection and LASSO (Interpretation)

# %% [markdown]
# In this notebook, you will use LASSO to select features, building on a pre-implemented solver for LASSO (using GraphLab Create, though you can use other solvers). You will:
# * Run LASSO with different L1 penalties.
# * Choose best L1 penalty using a validation set.
# * Choose best L1 penalty using a validation set, with additional constraint on the size of subset.
#
# In the second notebook, you will implement your own LASSO solver, using coordinate descent.

# %% [markdown]
# # Fire up graphlab create

# %%
import graphlab
# Out:
# [WARNING] Unable to write current GraphLab Create license to /Users/shraghavan/.graphlab/config. Ensure that this user account has write permission to /Users/shraghavan/.graphlab/config to save the license for offline use.
# [INFO] 1456616136 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_FILE to /Library/Python/2.7/site-packages/certifi/cacert.pem
# 1456616136 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_DIR to
# This non-commercial license of GraphLab Create is assigned to shankr@yahoo.com and will expire on November 22, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-18805 - Server binary: /Library/Python/2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1456616136.log
# [INFO] GraphLab Server Version: 1.7.1
# [WARNING] Unable to create session in specified location: '/Users/shraghavan/.graphlab/artifacts'. Using: '/var/tmp/graphlab-shraghavan/18805/tmp_session_21a01f3f-1f70-42bf-a278-19806209b259'

# %% [markdown]
# # Load in house sales data
#
# Dataset is from house sales in King County, the region where the city of Seattle, WA is located.

# %%
sales = graphlab.SFrame('kc_house_data.gl/')

# %% [markdown]
# # Create new features

# %% [markdown]
# As in Week 2, we consider features that are some transformations of inputs.

# %%
from math import log, sqrt
sales['sqft_living_sqrt'] = sales['sqft_living'].apply(sqrt)
sales['sqft_lot_sqrt'] = sales['sqft_lot'].apply(sqrt)
sales['bedrooms_square'] = sales['bedrooms']*sales['bedrooms']

# In the dataset, 'floors' was defined with type string, 
# so we'll convert them to float, before creating a new feature.
sales['floors'] = sales['floors'].astype(float) 
sales['floors_square'] = sales['floors']*sales['floors']

# %% [markdown]
# * Squaring bedrooms will increase the separation between not many bedrooms (e.g. 1) and lots of bedrooms (e.g. 4) since 1^2 = 1 but 4^2 = 16. Consequently this variable will mostly affect houses with many bedrooms.
# * On the other hand, taking square root of sqft_living will decrease the separation between big house and small house. The owner may not be exactly twice as happy for getting a house that is twice as big.

# %% [markdown]
# # Learn regression weights with L1 penalty

# %% [markdown]
# Let us fit a model with all the features available, plus the features we just created above.

# %%
all_features = ['bedrooms', 'bedrooms_square',
            'bathrooms',
            'sqft_living', 'sqft_living_sqrt',
            'sqft_lot', 'sqft_lot_sqrt',
            'floors', 'floors_square',
            'waterfront', 'view', 'condition', 'grade',
            'sqft_above',
            'sqft_basement',
            'yr_built', 'yr_renovated']

# %% [markdown]
# Applying L1 penalty requires adding an extra parameter (`l1_penalty`) to the linear regression call in GraphLab Create. (Other tools may have separate implementations of LASSO.)  Note that it's important to set `l2_penalty=0` to ensure we don't introduce an additional L2 penalty.

# %%
model_all = graphlab.linear_regression.create(sales, target='price', features=all_features,
                                              validation_set=None, 
                                              l2_penalty=0., l1_penalty=1e10)
# Out:
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 21613
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000002  | 0.273796     | 6962915.603493     | 426631.749026 |
# PROGRESS: | 2         | 3        | 0.000002  | 0.296369     | 6843144.200219     | 392488.929838 |
# PROGRESS: | 3         | 4        | 0.000002  | 0.321765     | 6831900.032123     | 385340.166783 |
# PROGRESS: | 4         | 5        | 0.000002  | 0.345307     | 6847166.848958     | 384842.383767 |
# PROGRESS: | 5         | 6        | 0.000002  | 0.367537     | 6869667.895833     | 385998.458623 |
# PROGRESS: | 6         | 7        | 0.000002  | 0.390610     | 6847177.773672     | 380824.455891 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.

# %% [markdown]
# Find what features had non-zero weight.

# %%
model_all.get("coefficients").print_rows(20,20)
# Out:
# +------------------+-------+---------------+
# |       name       | index |     value     |
# +------------------+-------+---------------+
# |   (intercept)    |  None |  274873.05595 |
# |     bedrooms     |  None |      0.0      |
# | bedrooms_square  |  None |      0.0      |
# |    bathrooms     |  None | 8468.53108691 |
# |   sqft_living    |  None | 24.4207209824 |
# | sqft_living_sqrt |  None | 350.060553386 |
# |     sqft_lot     |  None |      0.0      |
# |  sqft_lot_sqrt   |  None |      0.0      |
# |      floors      |  None |      0.0      |
# |  floors_square   |  None |      0.0      |
# |    waterfront    |  None |      0.0      |
# |       view       |  None |      0.0      |
# |    condition     |  None |      0.0      |
# |      grade       |  None | 842.068034898 |
# |    sqft_above    |  None | 20.0247224171 |
# |  sqft_basement   |  None |      0.0      |
# |     yr_built     |  None |      0.0      |
# |   yr_renovated   |  None |      0.0      |
# +------------------+-------+---------------+
# [18 rows x 3 columns]

# %% [markdown]
# Note that a majority of the weights have been set to zero. So by setting an L1 penalty that's large enough, we are performing a subset selection.
#
# ***QUIZ QUESTION***:
# According to this list of weights, which of the features have been chosen?

# %% [markdown]
# # Selecting an L1 penalty

# %% [markdown]
# To find a good L1 penalty, we will explore multiple values using a validation set. Let us do three way split into train, validation, and test sets:
# * Split our sales data into 2 sets: training and test
# * Further split our training data into two sets: train, validation
#
# Be *very* careful that you use seed = 1 to ensure you get the same answer!

# %%
(training_and_validation, testing) = sales.random_split(.9,seed=1) # initial train/test split
(training, validation) = training_and_validation.random_split(0.5, seed=1) # split training into train and validate

# %% [markdown]
# Next, we write a loop that does the following:
# * For `l1_penalty` in [10^1, 10^1.5, 10^2, 10^2.5, ..., 10^7] (to get this in Python, type `np.logspace(1, 7, num=13)`.)
#     * Fit a regression model with a given `l1_penalty` on TRAIN data. Specify `l1_penalty=l1_penalty` and `l2_penalty=0.` in the parameter list.
#     * Compute the RSS on VALIDATION data (here you will want to use `.predict()`) for that `l1_penalty`
# * Report which `l1_penalty` produced the lowest RSS on validation data.
#
# When you call `linear_regression.create()` make sure you set `validation_set = None`.
#
# Note: you can turn off the print out of `linear_regression.create()` with `verbose = False`

# %%
def get_residual_sum_of_squares(model, data, outcome):
    # First get the predictions
    predictions = model.predict(data)
    # Then compute the residuals/errors
    residuals = predictions - data['price']

    # Then square and add them up
    RSS = (residuals * residuals).sum()
    return(RSS)

# %%
import numpy as np

# %%
rss_list = []
for l1_penalty in np.logspace(1, 7, num=13):
    model = graphlab.linear_regression.create(training, target='price', features=all_features,
                                              validation_set=None, 
                                              l2_penalty=0., l1_penalty=l1_penalty)
    rss = get_residual_sum_of_squares(model, validation, validation["price"])
    rss_list.append(rss)
    if (len(rss_list) == 1):
        min_l1_penalty = l1_penalty
        min_rss = rss
    else:
        if min_rss > rss:
            min_rss = rss
            min_l1_penalty = l1_penalty
print min_rss, min_l1_penalty
print rss
# Out:
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.315489     | 6287414.310279     | 322429.554621 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.346990     | 6004129.870008     | 303352.364502 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.375413     | 5888882.499599     | 298370.510858 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.403511     | 5813781.207975     | 293774.670687 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.432294     | 5737572.318059     | 289374.784200 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.460525     | 5655864.782013     | 285354.826809 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.311060     | 6287414.313562     | 322429.554953 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.339900     | 6004129.874269     | 303352.364626 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.368648     | 5888882.504575     | 298370.510940 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.397965     | 5813781.213635     | 293774.670786 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.427713     | 5737572.324432     | 289374.784313 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.459304     | 5655864.789116     | 285354.826924 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.336728     | 6287414.323944     | 322429.556003 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.364661     | 6004129.887744     | 303352.365020 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.392915     | 5888882.520311     | 298370.511200 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.419373     | 5813781.231534     | 293774.671099 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.449675     | 5737572.344586     | 289374.784672 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.475979     | 5655864.811580     | 285354.827288 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.322770     | 6287414.356773     | 322429.559323 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.349267     | 6004129.930357     | 303352.366264 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.379762     | 5888882.570072     | 298370.512023 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.408579     | 5813781.288134     | 293774.672088 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.434924     | 5737572.408316     | 289374.785805 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.464351     | 5655864.882615     | 285354.828441 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.328254     | 6287414.460587     | 322429.569820 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.355571     | 6004130.065110     | 303352.370200 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.385358     | 5888882.727430     | 298370.514625 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.414185     | 5813781.467118     | 293774.675217 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.441115     | 5737572.609850     | 289374.789391 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.470149     | 5655865.107248     | 285354.832084 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.330855     | 6287414.788876     | 322429.603015 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.356823     | 6004130.491238     | 303352.382646 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.385536     | 5888883.225042     | 298370.522854 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.412793     | 5813782.033117     | 293774.685112 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.442677     | 5737573.247157     | 289374.800728 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.469562     | 5655865.817602     | 285354.843605 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.326310     | 6287415.827019     | 322429.707988 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.352535     | 6004131.838771     | 303352.422004 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.385550     | 5888884.798629     | 298370.548875 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.418272     | 5813783.822962     | 293774.716403 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.447949     | 5737575.262497     | 289374.836581 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.476788     | 5655868.063937     | 285354.880039 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.322729     | 6287419.109914     | 322430.039943 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.355280     | 6004136.100045     | 303352.546466 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.387459     | 5888889.774746     | 298370.631163 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.417048     | 5813789.482948     | 293774.815357 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.446166     | 5737581.635561     | 289374.949962 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.474101     | 5655875.167473     | 285354.995257 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.313299     | 6287429.491340     | 322431.089695 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.340828     | 6004149.575378     | 303352.940082 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.367293     | 5888905.510609     | 298370.891417 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.395045     | 5813807.381396     | 293775.128315 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.422241     | 5737601.788960     | 289375.308545 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.450225     | 5655897.630825     | 285355.359658 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.317889     | 6287462.320295     | 322434.409477 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.346420     | 6004192.188124     | 303354.185095 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.372576     | 5888955.271783     | 298371.714747 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.400562     | 5813863.981264     | 293776.118347 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.430157     | 5737665.519606     | 289376.442902 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.457693     | 5655968.666186     | 285356.512471 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.322935     | 6287566.134553     | 322444.909304 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.351656     | 6004326.941447     | 303358.125094 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.379501     | 5889112.630416     | 298374.321707 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.407568     | 5814042.965743     | 293779.252821 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.434076     | 5737867.053589     | 289380.034238 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.464170     | 5656193.299699     | 285360.162764 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.317148     | 6287894.424085     | 322478.130206 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.344721     | 6004753.068898     | 303370.613672 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.372905     | 5889610.242137     | 298382.599251 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.401261     | 5814608.964400     | 293789.202075 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.429956     | 5738504.360039     | 289391.432870 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.457642     | 5656903.653287     | 285371.753783 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.326079     | 6288932.566682     | 322583.359172 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.357082     | 6006100.602140     | 303410.398042 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.384853     | 5891183.828480     | 298409.111215 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.412968     | 5816398.809211     | 293821.036075 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.442446     | 5740519.699879     | 289427.896727 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.469010     | 5659149.988446     | 285408.885485 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# 6.25766285142e+14 10.0
# 6.25883719085e+14

# %% [markdown]
# *** QUIZ QUESTIONS ***
# 1. What was the best value for the `l1_penalty`?
# 2. What is the RSS on TEST data of the model with the best `l1_penalty`?

# %%
model = graphlab.linear_regression.create(training, target='price', features=all_features,
                                              validation_set=None, 
                                              l2_penalty=0., l1_penalty=10.)
# Out:
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.316587     | 6287414.310279     | 322429.554621 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.343553     | 6004129.870008     | 303352.364502 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.371526     | 5888882.499599     | 298370.510858 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.399679     | 5813781.207975     | 293774.670687 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.431378     | 5737572.318059     | 289374.784200 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.458094     | 5655864.782013     | 285354.826809 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.

# %% [markdown]
# ***QUIZ QUESTION***
# Also, using this value of L1 penalty, how many nonzero weights do you have?

# %%
model.get("coefficients").print_rows(20)
# Out:
# +------------------+-------+------------------+
# |       name       | index |      value       |
# +------------------+-------+------------------+
# |   (intercept)    |  None |  18993.4272128   |
# |     bedrooms     |  None |  7936.96767903   |
# | bedrooms_square  |  None |  936.993368193   |
# |    bathrooms     |  None |  25409.5889341   |
# |   sqft_living    |  None |  39.1151363797   |
# | sqft_living_sqrt |  None |  1124.65021281   |
# |     sqft_lot     |  None | 0.00348361822299 |
# |  sqft_lot_sqrt   |  None |  148.258391011   |
# |      floors      |  None |   21204.335467   |
# |  floors_square   |  None |  12915.5243361   |
# |    waterfront    |  None |  601905.594545   |
# |       view       |  None |  93312.8573119   |
# |    condition     |  None |  6609.03571245   |
# |      grade       |  None |  6206.93999188   |
# |    sqft_above    |  None |  43.2870534193   |
# |  sqft_basement   |  None |  122.367827534   |
# |     yr_built     |  None |  9.43363539372   |
# |   yr_renovated   |  None |  56.0720034488   |
# +------------------+-------+------------------+
# [18 rows x 3 columns]

# %% [markdown]
# # Limit the number of nonzero weights
#
# What if we absolutely wanted to limit ourselves to, say, 7 features? This may be important if we want to derive "a rule of thumb" --- an interpretable model that has only a few features in them.

# %% [markdown]
# In this section, you are going to implement a simple, two phase procedure to achive this goal:
# 1. Explore a large range of `l1_penalty` values to find a narrow region of `l1_penalty` values where models are likely to have the desired number of non-zero weights.
# 2. Further explore the narrow region you found to find a good value for `l1_penalty` that achieves the desired sparsity.  Here, we will again use a validation set to choose the best value for `l1_penalty`.

# %%
max_nonzeros = 7

# %% [markdown]
# ## Exploring the larger range of values to find a narrow range with the desired sparsity
#
# Let's define a wide range of possible `l1_penalty_values`:

# %%
l1_penalty_values = np.logspace(8, 10, num=20)

# %% [markdown]
# Now, implement a loop that search through this space of possible `l1_penalty` values:
#
# * For `l1_penalty` in `np.logspace(8, 10, num=20)`:
#     * Fit a regression model with a given `l1_penalty` on TRAIN data. Specify `l1_penalty=l1_penalty` and `l2_penalty=0.` in the parameter list. When you call `linear_regression.create()` make sure you set `validation_set = None`
#     * Extract the weights of the model and count the number of nonzeros. Save the number of nonzeros to a list.
#         * *Hint: `model['coefficients']['value']` gives you an SArray with the parameters you learned.  If you call the method `.nnz()` on it, you will find the number of non-zero parameters!*

# %%
more_than_maxnonzeros_l1_penalties = []
less_than_maxnonzeros_l1_penalties = []
for l1_penalty in l1_penalty_values:
    model = graphlab.linear_regression.create(training, target='price', features=all_features,
                                              validation_set=None, 
                                              l2_penalty=0., l1_penalty=l1_penalty)
    non_zeros_count = model['coefficients']['value'].nnz()
    if non_zeros_count > max_nonzeros:
        more_than_maxnonzeros_l1_penalties.append((l1_penalty, non_zeros_count))
    if non_zeros_count < max_nonzeros:
        less_than_maxnonzeros_l1_penalties.append((l1_penalty, non_zeros_count))
    
print more_than_maxnonzeros_l1_penalties
print less_than_maxnonzeros_l1_penalties
# Out:
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.329480     | 6302596.887972     | 323993.114447 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.361299     | 6023837.209073     | 303975.326597 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.387604     | 5911895.809122     | 298805.600064 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.416967     | 5839957.243889     | 294292.598204 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.444236     | 5767046.162784     | 289966.959726 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.475770     | 5688716.875912     | 285965.139010 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.320388     | 6306761.089277     | 324431.811110 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.348807     | 6029242.439247     | 304162.702383 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.376843     | 5918207.784303     | 298943.962355 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.406795     | 5847136.675810     | 294455.684490 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.434654     | 5775130.101176     | 290153.028407 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.463642     | 5697727.383553     | 286159.539614 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.329104     | 6312067.428647     | 324996.927681 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.357184     | 6036130.191201     | 304411.734396 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.386459     | 5926250.979130     | 299132.112018 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.415118     | 5856285.249441     | 294676.578872 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.441717     | 5785431.265169     | 290404.829180 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.469884     | 5709209.251967     | 286424.040727 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.325121     | 6318829.161558     | 325726.887556 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.353645     | 6044907.077830     | 304745.693519 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.382782     | 5936500.217141     | 299391.051314 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.413983     | 5867943.043467     | 294979.244899 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.442766     | 5798557.775695     | 290749.495050 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.472947     | 5723840.304020     | 286788.259115 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.332564     | 6327445.469597     | 326672.935878 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.366277     | 6056091.246122     | 305198.151982 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.395744     | 5949560.566172     | 299752.080188 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.422864     | 5882798.280387     | 295399.217084 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.452178     | 5815284.561515     | 291227.202999 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.483829     | 5742484.289679     | 287296.320924 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.336643     | 6338425.015323     | 327904.016823 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.366004     | 6070342.951911     | 305818.193076 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.395343     | 5966203.042130     | 300262.391571 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.425456     | 5901727.937067     | 295989.815933 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.456781     | 5836599.086125     | 291898.147485 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.483709     | 5766241.854070     | 288014.702465 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.349363     | 6352415.978265     | 329513.773176 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.383270     | 6088503.547309     | 306678.464467 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.412075     | 5987410.136686     | 300993.852916 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.440953     | 5925849.529320     | 296831.866711 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.469121     | 5863759.656463     | 292853.418793 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.497500     | 5796515.529440     | 289044.471466 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.334925     | 6370244.310167     | 331630.660676 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.364518     | 6111645.136891     | 307887.639691 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.393597     | 6014433.803461     | 302056.769305 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.422982     | 5956587.067149     | 298048.868696 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.451841     | 5898369.687568     | 294231.926395 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.482890     | 5835068.031486     | 290539.467795 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.333945     | 6392962.501428     | 334432.629813 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.368881     | 6141133.877684     | 309609.652192 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.398300     | 6048869.376781     | 303621.347701 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.428074     | 5995755.132177     | 299830.533427 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.457428     | 5942472.372582     | 296246.537804 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.489773     | 5882772.472167     | 292655.514067 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.332169     | 6421911.739799     | 338168.430249 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.361022     | 6178710.662590     | 312093.147503 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.390642     | 6092749.790017     | 305950.822078 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.421068     | 6045666.044451     | 302468.872046 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.450398     | 5998277.020726     | 299195.437483 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.477717     | 5944444.613403     | 295775.972512 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.336107     | 6458801.015264     | 343188.313914 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.366887     | 6226593.800368     | 315715.881133 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.396220     | 6148665.480461     | 309451.624488 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.430523     | 6109266.245878     | 306412.359795 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.459894     | 6067941.501592     | 303417.317296 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.486968     | 6019163.317913     | 300393.085687 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.329789     | 6505808.107267     | 349987.699359 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.358742     | 6287610.099403     | 321049.939717 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.386232     | 6219917.462832     | 314747.103160 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.415234     | 6186864.205766     | 312133.200443 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.443189     | 6141049.702542     | 309268.413008 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.473197     | 6098090.379557     | 306911.599029 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.331512     | 6565708.060916     | 359267.674436 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.359908     | 6365361.632804     | 328953.510730 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.388714     | 6305829.246141     | 322613.170450 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.416588     | 6265428.838674     | 319852.473118 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.443930     | 6233853.106449     | 318320.600901 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.472999     | 6199198.857716     | 316732.370565 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.314177     | 6642037.071382     | 372015.681824 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.342064     | 6461738.956416     | 340588.423328 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.368859     | 6398392.723924     | 333431.863633 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.401424     | 6371877.122886     | 331286.359425 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.428158     | 6353136.654069     | 330421.269864 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.458901     | 6330612.934807     | 329296.764297 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.322934     | 6739301.231007     | 389607.085142 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.352430     | 6569297.382654     | 356355.616933 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.380120     | 6519180.189446     | 348232.602946 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.409892     | 6511771.934086     | 347519.257327 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.437744     | 6508236.398022     | 347641.774942 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.467282     | 6496515.714757     | 346711.084406 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.333967     | 6851251.348758     | 412576.866347 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.362028     | 6705927.418436     | 378624.562082 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.391865     | 6678759.248861     | 371401.977561 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.421006     | 6689839.793283     | 371772.510021 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.451584     | 6700050.222874     | 372113.713871 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.479579     | 6697293.370032     | 370685.051067 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.325067     | 6990727.771524     | 443765.694135 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.352637     | 6881811.580352     | 411414.484829 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.379606     | 6872119.637764     | 404347.406375 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.407173     | 6884564.579949     | 402804.042129 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.435550     | 6884279.257633     | 400745.316819 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.461771     | 6869773.133183     | 397237.306904 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.316331     | 7165064.642471     | 485718.879258 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.344552     | 7086725.698544     | 456087.127286 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.372616     | 7075577.209652     | 446853.928812 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.402313     | 7062536.185828     | 441456.188174 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.429927     | 7054349.178409     | 436331.029744 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.460309     | 7053909.066828     | 430723.907200 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000005  | 0.320387     | 7202439.442101     | 484432.625377 |
# PROGRESS: | 2         | 3        | 0.000005  | 0.349856     | 7284840.298565     | 505076.954827 |
# PROGRESS: | 3         | 4        | 0.000005  | 0.377661     | 7266438.445660     | 490990.237855 |
# PROGRESS: | 4         | 5        | 0.000005  | 0.406500     | 7270633.139688     | 473802.625159 |
# PROGRESS: | 5         | 6        | 0.000005  | 0.435560     | 7320904.689497     | 462020.358653 |
# PROGRESS: | 6         | 7        | 0.000005  | 0.464659     | 7344719.665332     | 441190.123985 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000012  | 0.300671     | 7228843.829153     | 476257.577720 |
# PROGRESS: | 2         | 3        | 0.000012  | 0.327389     | 7504641.811821     | 514487.205685 |
# PROGRESS: | 3         | 4        | 0.000012  | 0.354524     | 7402647.878877     | 451928.315910 |
# PROGRESS: | 4         | 5        | 0.000012  | 0.383182     | 7312309.081776     | 409957.463247 |
# PROGRESS: | 5         | 6        | 0.000012  | 0.410691     | 7239807.218168     | 388380.843122 |
# PROGRESS: | 6         | 7        | 0.000012  | 0.437998     | 7187431.218291     | 380705.223778 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# [(100000000.0, 18), (127427498.57031322, 18), (162377673.91887242, 18), (206913808.11147901, 18), (263665089.87303555, 17), (335981828.62837881, 17), (428133239.8719396, 17), (545559478.11685145, 17), (695192796.17755914, 17), (885866790.41008317, 16), (1128837891.6846883, 15), (1438449888.2876658, 15), (1832980710.8324375, 13), (2335721469.0901213, 12), (2976351441.6313133, 10)]
# [(3792690190.7322536, 6), (4832930238.5717525, 5), (6158482110.6602545, 3), (7847599703.5146227, 1), (10000000000.0, 1)]

# %% [markdown]
# Out of this large range, we want to find the two ends of our desired narrow range of `l1_penalty`.  At one end, we will have `l1_penalty` values that have too few non-zeros, and at the other end, we will have an `l1_penalty` that has too many non-zeros.
#
# More formally, find:
# * The largest `l1_penalty` that has more non-zeros than `max_nonzero` (if we pick a penalty smaller than this value, we will definitely have too many non-zero weights)
#     * Store this value in the variable `l1_penalty_min` (we will use it later)
# * The smallest `l1_penalty` that has fewer non-zeros than `max_nonzero` (if we pick a penalty larger than this value, we will definitely have too few non-zero weights)
#     * Store this value in the variable `l1_penalty_max` (we will use it later)
#
#
# *Hint: there are many ways to do this, e.g.:*
# * Programmatically within the loop above
# * Creating a list with the number of non-zeros for each value of `l1_penalty` and inspecting it to find the appropriate boundaries.

# %%
l1_penalty_min = 2976351441.6
l1_penalty_max = 3792690190.7

# %% [markdown]
# ***QUIZ QUESTIONS***
#
# What values did you find for `l1_penalty_min` and`l1_penalty_max`?

# %% [markdown]
# ## Exploring the narrow range of values to find the solution with the right number of non-zeros that has lowest RSS on the validation set
#
# We will now explore the narrow region of `l1_penalty` values we found:

# %%
l1_penalty_values = np.linspace(l1_penalty_min,l1_penalty_max,20)

# %%
l1_penalty_values
# Out:
# array([  2.97635144e+09,   3.01931664e+09,   3.06228184e+09,
#          3.10524703e+09,   3.14821223e+09,   3.19117743e+09,
#          3.23414263e+09,   3.27710782e+09,   3.32007302e+09,
#          3.36303822e+09,   3.40600341e+09,   3.44896861e+09,
#          3.49193381e+09,   3.53489901e+09,   3.57786420e+09,
#          3.62082940e+09,   3.66379460e+09,   3.70675980e+09,
#          3.74972499e+09,   3.79269019e+09])

# %% [markdown]
# * For `l1_penalty` in `np.linspace(l1_penalty_min,l1_penalty_max,20)`:
#     * Fit a regression model with a given `l1_penalty` on TRAIN data. Specify `l1_penalty=l1_penalty` and `l2_penalty=0.` in the parameter list. When you call `linear_regression.create()` make sure you set `validation_set = None`
#     * Measure the RSS of the learned model on the VALIDATION set
#
# Find the model that the lowest RSS on the VALIDATION set and has sparsity *equal* to `max_nonzero`.

# %%
rss_list = []
for l1_penalty in np.linspace(l1_penalty_min,l1_penalty_max,20):
    #print "l1_penalty: " + str(l1_penalty)
    model = graphlab.linear_regression.create(training, target='price', features=all_features,
                                              validation_set=None, 
                                              l2_penalty=0., l1_penalty=l1_penalty)
    rss = get_residual_sum_of_squares(model, validation, validation["price"])
    if model["coefficients"]['value'].nnz() == max_nonzeros:
        rss_list.append(rss)
        if (len(rss_list) == 1):
            min_l1_penalty = l1_penalty
            min_rss = rss
            min_rss_model = model
        else:
            if min_rss > rss:
                min_rss = rss
                min_l1_penalty = l1_penalty
                min_rss_model = model
        print "min_l1_penalty: " + str(min_l1_penalty)
        print "l1_penalty:" + str(l1_penalty)
        print model.get("coefficients").print_rows(num_rows=20)
print min_rss, min_l1_penalty
#print min_rss_model.get("coefficients")
# Out:
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.320385     | 6739301.231007     | 389607.085142 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.349035     | 6569297.382654     | 356355.616933 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.379533     | 6519180.189446     | 348232.602946 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.409280     | 6511771.934086     | 347519.257327 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.437511     | 6508236.398022     | 347641.774942 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.464733     | 6496515.714757     | 346711.084406 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.316266     | 6745824.463817     | 390816.789246 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.342382     | 6576394.847047     | 357433.566852 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.369025     | 6527572.935664     | 349357.366319 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.396382     | 6521142.806632     | 348701.019139 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.423808     | 6518614.014289     | 348888.199260 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.452598     | 6507128.891315     | 347885.665556 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.323767     | 6752347.657761     | 392009.121753 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.352519     | 6583521.070903     | 358524.867897 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.380443     | 6535971.427822     | 350493.642380 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.410715     | 6530517.602470     | 349894.204388 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.438763     | 6528996.173933     | 350146.209214 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.466107     | 6517746.461337     | 349069.317383 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.321682     | 6758338.328596     | 393183.638571 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.352004     | 6590703.295167     | 359634.836047 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.379185     | 6544370.536454     | 351640.727736 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.407955     | 6539890.228171     | 351097.892318 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.435523     | 6539379.516775     | 351415.297011 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.464854     | 6528366.248329     | 350261.721339 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.333708     | 6764145.398843     | 394355.637359 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.363171     | 6597904.810916     | 360757.199941 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.393719     | 6552769.840363     | 352798.630865 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.419205     | 6549262.086461     | 352312.355494 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.447273     | 6549763.246198     | 352695.353562 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.476051     | 6538986.777810     | 351462.667919 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.319573     | 6769952.469091     | 395533.206039 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.347891     | 6605106.326666     | 361888.548761 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.377593     | 6561169.144272     | 353967.313247 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.407271     | 6558633.944750     | 353537.695247 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.437168     | 6560146.975621     | 353986.270792 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.466490     | 6549607.307292     | 352672.009019 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.334299     | 6775759.539339     | 396716.295011 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.362596     | 6612307.842416     | 363028.798505 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.388404     | 6569568.448181     | 355146.668469 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.415160     | 6568005.803040     | 354773.798877 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.442279     | 6570530.705045     | 355287.930317 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.469944     | 6560227.836773     | 353889.658579 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.316683     | 6781566.574986     | 397904.847937 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.347556     | 6619509.315257     | 364177.858692 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.373991     | 6577967.702044     | 356336.583438 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.403962     | 6577377.605489     | 356020.546809 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.433591     | 6580914.372598     | 356600.206652 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.462543     | 6570848.302974     | 355115.523804 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.315072     | 6787373.645234     | 399098.830100 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.341148     | 6626710.831006     | 365335.659819 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.370830     | 6586367.005953     | 357536.966832 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.398878     | 6586749.463778     | 357277.842388 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.425347     | 6591298.102022     | 357922.998572 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.451556     | 6581468.832455     | 356349.534440 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.320409     | 6793180.715481     | 400298.185918 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.347745     | 6633912.346756     | 366502.112290 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.380456     | 6594766.309862     | 358747.706580 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.407280     | 6596121.322068     | 358545.567335 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.434910     | 6601681.831445     | 359256.182222 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.462477     | 6592089.361936     | 357591.598955 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.313525     | 6798987.785729     | 401502.867233 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.339315     | 6641113.862506     | 367677.133766 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.366835     | 6603165.613771     | 359968.698182 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.394459     | 6605493.180357     | 359823.611417 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.422033     | 6612065.560868     | 360599.642341 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.449615     | 6602709.891417     | 358841.633718 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.318113     | 6804794.855977     | 402712.826253 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.344120     | 6648315.378256     | 368860.642357 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.371698     | 6611564.917680     | 361199.837673 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.398816     | 6614865.038647     | 361111.865068 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.425536     | 6622449.290291     | 361953.264500 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.451831     | 6613330.420898     | 360099.555727 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# min_l1_penalty: 3448968612.13
# l1_penalty:3448968612.13
# +------------------+-------+---------------+
# |       name       | index |     value     |
# +------------------+-------+---------------+
# |   (intercept)    |  None | 222253.192544 |
# |     bedrooms     |  None | 661.722717782 |
# | bedrooms_square  |  None |      0.0      |
# |    bathrooms     |  None | 15873.9572593 |
# |   sqft_living    |  None | 32.4102214513 |
# | sqft_living_sqrt |  None | 690.114773313 |
# |     sqft_lot     |  None |      0.0      |
# |  sqft_lot_sqrt   |  None |      0.0      |
# |      floors      |  None |      0.0      |
# |  floors_square   |  None |      0.0      |
# |    waterfront    |  None |      0.0      |
# |       view       |  None |      0.0      |
# |    condition     |  None |      0.0      |
# |      grade       |  None | 2899.42026975 |
# |    sqft_above    |  None | 30.0115753022 |
# |  sqft_basement   |  None |      0.0      |
# |     yr_built     |  None |      0.0      |
# |   yr_renovated   |  None |      0.0      |
# +------------------+-------+---------------+
# [18 rows x 3 columns]
#
# None
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.312239     | 6810601.891624     | 403928.008294 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.338369     | 6655516.851097     | 370052.549506 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.364160     | 6619964.171543     | 362441.014218 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.391321     | 6624236.841096     | 362410.211648 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.419724     | 6632388.356592     | 363238.633808 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.448250     | 6624497.937274     | 361462.325873 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# min_l1_penalty: 3448968612.13
# l1_penalty:3491933809.45
# +------------------+-------+---------------+
# |       name       | index |     value     |
# +------------------+-------+---------------+
# |   (intercept)    |  None | 224545.136501 |
# |     bedrooms     |  None | 496.983429977 |
# | bedrooms_square  |  None |      0.0      |
# |    bathrooms     |  None | 15640.8229131 |
# |   sqft_living    |  None | 32.2039341994 |
# | sqft_living_sqrt |  None | 678.904419357 |
# |     sqft_lot     |  None |      0.0      |
# |  sqft_lot_sqrt   |  None |      0.0      |
# |      floors      |  None |      0.0      |
# |  floors_square   |  None |      0.0      |
# |    waterfront    |  None |      0.0      |
# |       view       |  None |      0.0      |
# |    condition     |  None |      0.0      |
# |      grade       |  None |  2825.4694254 |
# |    sqft_above    |  None |  29.715599776 |
# |  sqft_basement   |  None |      0.0      |
# |     yr_built     |  None |      0.0      |
# |   yr_renovated   |  None |      0.0      |
# +------------------+-------+---------------+
# [18 rows x 3 columns]
#
# None
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.345071     | 6816408.961872     | 405148.380776 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.375867     | 6662718.366846     | 371252.788456 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.405393     | 6628363.475452     | 363692.139769 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.436101     | 6633608.699386     | 363718.558461 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.462345     | 6642054.345717     | 364484.037875 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.492361     | 6636001.595070     | 362894.485099 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# min_l1_penalty: 3448968612.13
# l1_penalty:3534899006.77
# +------------------+-------+---------------+
# |       name       | index |     value     |
# +------------------+-------+---------------+
# |   (intercept)    |  None | 226807.047234 |
# |     bedrooms     |  None | 322.098888436 |
# | bedrooms_square  |  None |      0.0      |
# |    bathrooms     |  None | 15392.9565223 |
# |   sqft_living    |  None | 31.9817554069 |
# | sqft_living_sqrt |  None | 666.949904077 |
# |     sqft_lot     |  None |      0.0      |
# |  sqft_lot_sqrt   |  None |      0.0      |
# |      floors      |  None |      0.0      |
# |  floors_square   |  None |      0.0      |
# |    waterfront    |  None |      0.0      |
# |       view       |  None |      0.0      |
# |    condition     |  None |      0.0      |
# |      grade       |  None | 2747.52787565 |
# |    sqft_above    |  None | 29.4061078857 |
# |  sqft_basement   |  None |      0.0      |
# |     yr_built     |  None |      0.0      |
# |   yr_renovated   |  None |      0.0      |
# +------------------+-------+---------------+
# [18 rows x 3 columns]
#
# None
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.314524     | 6822216.032119     | 406373.889776 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.342670     | 6669919.882596     | 372461.271652 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.372153     | 6636762.779361     | 364953.104716 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.400996     | 6642980.557675     | 365036.790356 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.429265     | 6651720.334842     | 365737.059513 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.458279     | 6647505.252865     | 364336.765726 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# min_l1_penalty: 3448968612.13
# l1_penalty:3577864204.09
# +------------------+-------+---------------+
# |       name       | index |     value     |
# +------------------+-------+---------------+
# |   (intercept)    |  None | 229077.875448 |
# |     bedrooms     |  None | 149.417508491 |
# | bedrooms_square  |  None |      0.0      |
# |    bathrooms     |  None | 15146.7392756 |
# |   sqft_living    |  None | 31.7586377842 |
# | sqft_living_sqrt |  None |  655.07824878 |
# |     sqft_lot     |  None |      0.0      |
# |  sqft_lot_sqrt   |  None |      0.0      |
# |      floors      |  None |      0.0      |
# |  floors_square   |  None |      0.0      |
# |    waterfront    |  None |      0.0      |
# |       view       |  None |      0.0      |
# |    condition     |  None |      0.0      |
# |      grade       |  None | 2670.25064395 |
# |    sqft_above    |  None | 29.0979663052 |
# |  sqft_basement   |  None |      0.0      |
# |     yr_built     |  None |      0.0      |
# |   yr_renovated   |  None |      0.0      |
# +------------------+-------+---------------+
# [18 rows x 3 columns]
#
# None
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.339072     | 6828023.102367     | 407604.488964 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.367897     | 6677121.398346     | 373677.919108 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.402901     | 6645162.083270     | 366223.807423 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.435304     | 6652352.415965     | 366364.800631 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.465073     | 6661386.323967     | 366997.620697 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.494126     | 6659008.910661     | 365789.048032 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.339392     | 6833830.172615     | 408840.132375 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.367130     | 6684322.914096     | 374902.651339 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.394234     | 6653561.387179     | 367504.146882 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.423227     | 6661724.274254     | 367702.483336 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.451881     | 6671052.313092     | 368265.644004 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.480673     | 6670512.568457     | 367251.213363 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.333815     | 6839637.208262     | 410080.767006 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.363340     | 6691524.386936     | 376135.382003 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.393101     | 6661960.641043     | 368794.015010 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.424598     | 6671096.076703     | 369049.725239 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.452839     | 6680718.244624     | 369541.044998 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.480100     | 6679542.716608     | 368401.661442 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.330618     | 6845444.278510     | 411326.362411 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.360623     | 6698725.902686     | 377376.047334 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.389572     | 6670359.944952     | 370093.327468 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.420963     | 6680467.934993     | 370406.438000 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.452176     | 6690384.233749     | 370823.762675 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.482217     | 6688418.043320     | 369539.610571 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 9761
# PROGRESS: Number of features          : 17
# PROGRESS: Number of unpacked features : 17
# PROGRESS: Number of coefficients    : 18
# PROGRESS: Starting Accelerated Gradient (FISTA)
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Step size | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: Tuning step size. First iteration could take longer than subsequent iterations.
# PROGRESS: | 1         | 2        | 0.000003  | 0.333153     | 6851251.348758     | 412576.866347 |
# PROGRESS: | 2         | 3        | 0.000003  | 0.361867     | 6705927.418436     | 378624.562082 |
# PROGRESS: | 3         | 4        | 0.000003  | 0.391235     | 6678759.248861     | 371401.977561 |
# PROGRESS: | 4         | 5        | 0.000003  | 0.422390     | 6689839.793283     | 371772.510021 |
# PROGRESS: | 5         | 6        | 0.000003  | 0.452421     | 6700050.222874     | 372113.713871 |
# PROGRESS: | 6         | 7        | 0.000003  | 0.481926     | 6697293.370032     | 370685.051067 |
# PROGRESS: +-----------+----------+-----------+--------------+--------------------+---------------+
# PROGRESS: TERMINATED: Iteration limit reached.
# PROGRESS: This model may not be optimal. To improve it, consider increasing `max_iterations`.
# 1.04693748875e+15 3448968612.13

# %% [markdown]
# ***QUIZ QUESTIONS***
# 1. What value of `l1_penalty` in our narrow range has the lowest RSS on the VALIDATION set and has sparsity *equal* to `max_nonzeros`?
# 2. What features in this model have non-zero coefficients?

# %%
min_rss_model.get("coefficients")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-293a0552ef6c> in <module>()
# ----> 1 min_rss_model.get("coefficients")
#
# NameError: name 'min_rss_model' is not defined
